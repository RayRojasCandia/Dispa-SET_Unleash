# %% [markdown]
# <div style="text-align: center; margin-left: 0em; font-weight: bold; font-size: 20px; font-family: TimesNewRoman;">
#     POWER PLANTS DATA PROCESSING - Main Notebook
# </div>
# <div style="text-align: left; margin-left: 0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Each part of the following script was used to proccess the raw data for power plants units of the Dispa-SET_Unleash project.
#     <br>
#     Read explanation text cells to follow and understand all the process until final results were got stept by step.
# </div>
# <br>
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     1. Notebook Set Up
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Importing needed libraries
# </div>

# %%
import os
import csv
from datetime import datetime
import requests
import pandas as pd
from shutil import move
import numpy as np
import shutil
import pandas as pd

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     2. Dispa-SET_Unleash Folder Path
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Determinning dynamically the zone_folder_path based on the location of the "Dispa-SET_Unleash" folder relative to the current working directory.
# <br>
#     If the "Dispa-SET_Unleash" folder is copied to a different machine or location, the dispaSET_unleash_folder_path variable will automatically adjust accordingly.
# </div>

# %%
# Get the current working directory
current_directory = os.getcwd()

# Navigate to the parent directory of "Dispa-SET_Unleash"
dispaSET_unleash_parent_directory = os.path.dirname(current_directory)

# Get the path to the "Dispa-SET_Unleash" folder
dispaSET_unleash_folder_path = os.path.dirname(dispaSET_unleash_parent_directory)

# Construct the dispaSET_unleash_folder_name variable
dispaSET_unleash_folder_name = os.path.basename(dispaSET_unleash_folder_path)

print("dispaSET_unleash_folder_name:", dispaSET_unleash_folder_name)
print("dispaSET_unleash_folder_path:", dispaSET_unleash_folder_path)
# Out:
# dispaSET_unleash_folder_name: Dispa-SET_Unleash
# dispaSET_unleash_folder_path: /home/ray/Dispa-SET_Unleash

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     3. Zone(s) Creation
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Entering the zone name or names (in case of more than one zone wanted to be modelled) to create the folder where all data related to the corresponding zone are going to be storage
# </div>
# <div style="text-align: left; margin-left: 1.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     For European country names use the ISO 3166-1 standars i.e. AT, BE, BG, CH.... etc. to give the zone_name.
# <br>
#     For non European countries it would rather to call the zone_name with the same word of how it is defined in the data to be downloaded and processed. e.g.
# </div>
#     <div style="text-align: left; margin-left: 2.00em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#         If it is downloading a csv file with all power plants of Spain but just the units fo Pamplona city are wanted, and in the corresponding donwloaded file, Pamplona is refering with the acronim "PMPLN"; set the zone_name variable with the word "PMPLN".
# </div>

# %%
# List of folder names to create
zone_names = [
"AT",
"BE",
"BG",
"CH",
"CY",
"CZ",
"DE",
"DK",
"EE",
"EL",
"ES",
"FI",
"FR",
"HR",
"HU",
"IE",
"IT",
"LT",
"LU",
"LV",
"MT",
"NL",
"NO",
"PL",
"PT",
"RO",
"SE",
"SI",
"SK",
"UK"
]

# %% [markdown]
# <div style="text-align: left; margin-left: 4.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Saving the sub-folders and the files in a list.
#     The same will be used to return the folder to its original state after the procesing of the data.
# </div>

# %%
# Original value of dispaSET_unleash_folder_path
#dispaSET_unleash_folder_path = "/home/ray/Dispa-SET_Unleash"

# Additional string to be appended
additional_path = "/RawData/PowerPlants/"

# Construct the power_plants_raw_data_folder_path variable
power_plants_raw_data_folder_path = dispaSET_unleash_folder_path + additional_path
print("power_plants_raw_data_folder_path:", power_plants_raw_data_folder_path)

# List to store the names of folders and files
folder_file_names = []

# Function to read all folders and files inside the specified directory
def read_folder_contents(folder):
    for root, dirs, files in os.walk(folder):
        for name in dirs:
            folder_file_names.append(os.path.join(root, name))
        for name in files:
            folder_file_names.append(os.path.join(root, name))

# Read the folder contents
read_folder_contents(power_plants_raw_data_folder_path)

# Print the list of folder and file names
for name in folder_file_names:
    print(name)

# Optionally, return the list
folder_file_names
# Out:
# power_plants_raw_data_folder_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/.gitignore
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2024
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2017
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2020
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2019
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2018
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2016
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(22).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(1).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(12).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(27).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(32).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(4).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(20).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(16).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(31).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(18).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(24).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(29).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(17).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(0).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(13).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(5).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(33).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(3).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(2).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(15).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(28).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(26).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(14).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(8).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(30).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(19).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(11).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(6).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(21).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(25).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(23).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(7).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(9).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(10).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(28).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(12).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(19).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(5).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(4).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(27).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(14).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(24).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(25).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(22).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(2).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(21).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(1).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(30).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(23).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(29).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(32).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(3).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(33).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(16).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(10).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(18).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(20).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(26).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(17).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(31).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(11).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(0).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(7).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(9).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(6).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(13).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(15).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(8).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(24).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(22).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(11).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(33).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(27).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(31).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(1).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(12).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(21).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(29).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(5).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(10).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(9).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(19).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(32).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(0).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(25).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(3).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(13).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(6).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(28).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(26).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(23).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(2).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(17).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(8).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(16).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(7).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(15).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(4).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(30).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(18).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(14).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(20).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(1).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(31).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(16).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(12).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(30).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(0).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(21).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(20).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(2).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(9).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(11).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(8).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(17).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(25).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(10).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(6).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(18).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(13).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(24).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(32).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(19).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(14).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(26).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(23).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(33).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(15).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(22).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(28).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(5).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(4).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(27).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(29).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(7).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(3).csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/EU_Power_Units_Technical_Features
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/ENTSOE_Production_Type.csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/EU_Power_Units_Technical_Features.csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_CHPTypes.csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_clean_data_equivalent_headers.csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_fuels.csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_technologies.csv
# /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/EU_Power_Units_Technical_Features/EU_Power_Units_Technical_Features.csv
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/.gitignore',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2024',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2017',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2020',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2019',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2018',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2016',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(22).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(1).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(12).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(27).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(32).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(4).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(20).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(16).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(31).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(18).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(24).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(29).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(17).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(0).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(13).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(5).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(33).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(3).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(2).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(15).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(28).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(26).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(14).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(8).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(30).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(19).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(11).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(6).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(21).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(25).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(23).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(7).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(9).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2022/Installed Capacity Per Production Unit_202201010000-202301010000(10).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(28).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(12).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(19).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(5).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(4).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(27).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(14).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(24).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(25).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(22).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(2).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(21).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(1).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(30).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(23).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(29).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(32).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(3).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(33).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(16).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(10).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(18).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(20).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(26).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(17).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(31).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(11).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(0).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(7).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(9).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(6).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(13).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(15).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2014/Installed Capacity Per Production Unit_201401010000-201501010000(8).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(24).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(22).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(11).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(33).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(27).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(31).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(1).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(12).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(21).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(29).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(5).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(10).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(9).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(19).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(32).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(0).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(25).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(3).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(13).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(6).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(28).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(26).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(23).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(2).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(17).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(8).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(16).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(7).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(15).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(4).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(30).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(18).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(14).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2021/Installed Capacity Per Production Unit_202101010000-202201010000(20).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(1).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(31).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(16).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(12).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(30).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(0).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(21).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(20).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(2).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(9).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(11).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(8).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(17).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(25).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(10).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(6).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(18).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(13).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(24).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(32).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(19).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(14).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(26).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(23).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(33).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(15).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(22).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(28).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(5).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(4).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(27).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(29).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(7).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(3).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/EU_Power_Units_Technical_Features',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/ENTSOE_Production_Type.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/EU_Power_Units_Technical_Features.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_CHPTypes.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_clean_data_equivalent_headers.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_fuels.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_technologies.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/EU_Power_Units_Technical_Features/EU_Power_Units_Technical_Features.csv']

# %% [markdown]
# <div style="text-align: left; margin-left: 4.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Creating the zones (Countries modelled in Dispa-SET)
# </div>

# %%
# Dictionary to store created zone paths
created_zones = {}

# Create the zone
for zone_name in zone_names:
    zone_path = os.path.join(power_plants_raw_data_folder_path, zone_name)
    os.makedirs(zone_path, exist_ok=True)
    created_zones[zone_name] = zone_path
    print(f"Created zone: {zone_path}")

# Print the created zone paths
print("Created zones:")
for zone_name, zone_path in created_zones.items():
    print(f"{zone_name}: {zone_path}")
    
created_zones
# Out:
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK
# Created zone: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK
# Created zones:
# AT: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT
# BE: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE
# BG: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG
# CH: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH
# CY: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY
# CZ: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ
# DE: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE
# DK: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK
# EE: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE
# EL: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL
# ES: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES
# FI: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI
# FR: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR
# HR: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR
# HU: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU
# IE: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE
# IT: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT
# LT: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT
# LU: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU
# LV: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV
# MT: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT
# NL: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL
# NO: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO
# PL: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL
# PT: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT
# RO: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO
# SE: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE
# SI: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI
# SK: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK
# UK: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK
# {'AT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT',
#  'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE',
#  'BG': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG',
#  'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH',
#  'CY': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY',
#  'CZ': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ',
#  'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE',
#  'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK',
#  'EE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE',
#  'EL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL',
#  'ES': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES',
#  'FI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI',
#  'FR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR',
#  'HR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR',
#  'HU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU',
#  'IE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE',
#  'IT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT',
#  'LT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT',
#  'LU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU',
#  'LV': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV',
#  'MT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT',
#  'NL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL',
#  'NO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO',
#  'PL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL',
#  'PT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT',
#  'RO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO',
#  'SE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE',
#  'SI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI',
#  'SK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK',
#  'UK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'}

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
print (f"dispaSET_unleash_folder_name:                              {dispaSET_unleash_folder_name}")
print (f"dispaSET_unleash_folder_path:                              {dispaSET_unleash_folder_path}")
print (f"power_plants_raw_data_folder_path:                         {power_plants_raw_data_folder_path}")
print (f"zone_names:                                                {zone_names}")
print (f"created_zones:                                             {created_zones}")
# Out:
# dispaSET_unleash_folder_name:                              Dispa-SET_Unleash
# dispaSET_unleash_folder_path:                              /home/ray/Dispa-SET_Unleash
# power_plants_raw_data_folder_path:                         /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/
# zone_names:                                                ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK']
# created_zones:                                             {'AT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT', 'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE', 'BG': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG', 'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH', 'CY': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY', 'CZ': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ', 'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE', 'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK', 'EE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE', 'EL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL', 'ES': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES', 'FI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI', 'FR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR', 'HR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR', 'HU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU', 'IE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE', 'IT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT', 'LT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT', 'LU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU', 'LV': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV', 'MT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT', 'NL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL', 'NO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO', 'PL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL', 'PT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT', 'RO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO', 'SE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE', 'SI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI', 'SK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK', 'UK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'}

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     4. Raw Data Sources Path
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Entering all the files paths where the raw data is content.
#      <br>
#         If a set of files where all the power plants raw data is content, put them all in the local folder which path is:
#     <div style="text-align: left; margin-left: 1.0em; font-weight: unbold; font-size: 15px; font-family: TimesNewRoman;">
# /Local/Dispa_Set/Path/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/
#         </div>
#      Order them adding a number between pharentesys (), this ordernation is going to be saved by the variable sources_list.
#       <br>
#         That list is going to be saved to be used as input for next stages.
#       <br>
# </div>
#     <div style="text-align: left; margin-left: 1.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#         Notice that to process the data all the source files have to be .csv files.
# </div>
#     <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     In the other hand, it is important to define which zone is refering the file source.
# </div>
#     <div style="text-align: left; margin-left: 1.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     If all the source file contents data that belongs to only one zone, epecify it in the variable download_links_zone_related applying the same order than the variable sources_list.
#     <br>
#     If the source file contents data that refers different zones at the same time, specify it with the word "General" in the variable download_links_zone_related using the same order than the variable sources_list.
# </div>
#     <div style="text-align: left; margin-left: 2.0em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     Remember that the next filtering stages depend on the correct setting of this step.
# </div>
#     <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Additionally indicate the year of all data is referring to.
# </div>
#     <div style="text-align: left; margin-left: 1.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     This is going to be used as the name root under which all next files are going to be created.
# </div>

# %%
# Year to which data refers to:
data_year = '2023'

# %%
# Additional string to be appended
#additional_path_1 = "/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/"

# Construct the power_plants_raw_data_folder_path variable
#power_plants_raw_data_sources_folder_path = dispaSET_unleash_folder_path + additional_path_1
#print("power_plants_raw_data_sources_folder_path:", power_plants_raw_data_sources_folder_path)


additional_path_1 = "/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/"

# Create the power_plants_raw_data_sources_folder_path
power_plants_raw_data_sources_folder_path = dispaSET_unleash_folder_path + additional_path_1 + str(data_year) + "/"
print("power_plants_raw_data_sources_folder_path:", power_plants_raw_data_sources_folder_path)
# Out:
# power_plants_raw_data_sources_folder_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/

# %%
#power_plants_raw_data_sources_folder_path = "/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_ENTSOE_Raw_Data/"

# List to store the file paths
sources_list = []

# Function to extract the number from within parentheses
def extract_number(filename):
    start = filename.rfind('(') + 1
    end = filename.rfind(')')
    return int(filename[start:end])

# Iterate over all files in the folder
for root, dirs, files in os.walk(power_plants_raw_data_sources_folder_path):
    for file in files:
        # Construct the full file path
        file_path = os.path.join(root, file)
        # Append the file path to the source list
        sources_list.append(file_path)

# Sort the source list based on the numbers within parentheses
sources_list.sort(key=lambda x: extract_number(os.path.basename(x)))

# Print the sorted list of file paths
print(sources_list)

sources_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(0).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(1).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(2).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(3).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(4).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(5).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(6).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(7).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(8).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(9).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(10).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(11).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(12).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(13).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(14).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(15).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(16).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(17).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(18).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(19).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(20).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(21).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(22).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(23).csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(24).csv', '/home/ra ...
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(0).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(1).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(2).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(3).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(4).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(5).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(6).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(7).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(8).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(9).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(10).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(11).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(12).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(13).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(14).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(15).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(16).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(17).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(18).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(19).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(20).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(21).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(22).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(23).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(24).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(25).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(26).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(27).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(28).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(29).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(30).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(31).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(32).csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Raw_Data_Source/2023/Installed Capacity Per Production Unit_202301010000-202401010000(33).csv']

# %%
# List of the download links:
download_links = sources_list

# %%
# List of zones related to the download links:
download_links_zone_related = [
"AT",
"BE",
"BG",
"CH",
"CY",
"CZ",
"DE",
"DE",
"DE",
"DE",
"DK",
"EE",
"EL",
"ES",
"FI",
"FR",
"HR",
"HU",
"IE",
"IT",
"LT",
"LU",
"LV",
"MT",
"NL",
"NO",
"PL",
"PT",
"RO",
"SE",
"SI",
"SK",
"UK",
"UK"
]

# %%
def save_download_links_to_csv(links, zones, folder_path, data_year):
    # Create the filename using the data year, current date, and time
    now = datetime.now()
    timestamp = now.strftime("%Y%m%d_%H%M%S")
    file_name = f"{data_year}_power_plants_raw_data_sources_{timestamp}.csv"
    
    # Create a folder with the same name as the file (without extension)
    folder_name = os.path.splitext(file_name)[0]
    folder_path = os.path.join(folder_path, folder_name)
    os.makedirs(folder_path, exist_ok=True)
    
    # Combine the folder path and filename
    file_path = os.path.join(folder_path, file_name)
    
    # Write links to CSV file
    with open(file_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        
        # Write the header
        writer.writerow(['Download_Link_Sources', 'Zone', 'File_Name'])
        
        # Write the links, zones, and file names
        for i, (link, zone) in enumerate(zip(links, zones), start=1):
            writer.writerow([link, zone, i])
    
    print(f"Download links saved to: {file_path}")
    
    return file_path, file_name

# Save the download links to a CSV file and get the file path and name
power_plants_raw_data_sources_file_path, power_plants_raw_data_sources_file_name = save_download_links_to_csv(download_links, download_links_zone_related, power_plants_raw_data_folder_path, data_year)

print("File path:", power_plants_raw_data_sources_file_path)
print("File name:", power_plants_raw_data_sources_file_name)
# Out:
# Download links saved to: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240727_143238/2023_power_plants_raw_data_sources_20240727_143238.csv
# File path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240727_143238/2023_power_plants_raw_data_sources_20240727_143238.csv
# File name: 2023_power_plants_raw_data_sources_20240727_143238.csv

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
print (f"dispaSET_unleash_folder_name:                            {dispaSET_unleash_folder_name}")
print (f"dispaSET_unleash_folder_path:                            {dispaSET_unleash_folder_path}")
print (f"power_plants_raw_data_folder_path:                       {power_plants_raw_data_folder_path}")
print (f"zone_names:                                              {zone_names}")
print (f"created_zones:                                           {created_zones}")
print (f"power_plants_raw_data_sources_file_path:                 {power_plants_raw_data_sources_file_path}")
print (f"power_plants_raw_data_sources_file_name:                 {power_plants_raw_data_sources_file_name}")
print (f"data_year:                                               {data_year}")
print (f"download_links_zone_related:                             {download_links_zone_related}")
# Out:
# dispaSET_unleash_folder_name:                            Dispa-SET_Unleash
# dispaSET_unleash_folder_path:                            /home/ray/Dispa-SET_Unleash
# power_plants_raw_data_folder_path:                       /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/
# zone_names:                                              ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK']
# created_zones:                                           {'AT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT', 'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE', 'BG': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG', 'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH', 'CY': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY', 'CZ': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ', 'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE', 'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK', 'EE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE', 'EL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL', 'ES': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES', 'FI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI', 'FR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR', 'HR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR', 'HU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU', 'IE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE', 'IT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT', 'LT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT', 'LU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU', 'LV': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV', 'MT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT', 'NL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL', 'NO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO', 'PL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL', 'PT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT', 'RO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO', 'SE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE', 'SI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI', 'SK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK', 'UK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'}
# power_plants_raw_data_sources_file_path:                 /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240727_143238/2023_power_plants_raw_data_sources_20240727_143238.csv
# power_plants_raw_data_sources_file_name:                 2023_power_plants_raw_data_sources_20240727_143238.csv
# data_year:                                               2023
# download_links_zone_related:                             ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DE', 'DE', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK', 'UK']

# %%
created_zones
# Out:
# {'AT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT',
#  'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE',
#  'BG': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG',
#  'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH',
#  'CY': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY',
#  'CZ': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ',
#  'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE',
#  'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK',
#  'EE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE',
#  'EL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL',
#  'ES': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES',
#  'FI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI',
#  'FR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR',
#  'HR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR',
#  'HU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU',
#  'IE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE',
#  'IT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT',
#  'LT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT',
#  'LU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU',
#  'LV': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV',
#  'MT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT',
#  'NL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL',
#  'NO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO',
#  'PL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL',
#  'PT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT',
#  'RO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO',
#  'SE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE',
#  'SI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI',
#  'SK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK',
#  'UK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'}

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     5. Power Plants Raw Data Download Files
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Using the download list given previously to download and save all the power units raw data files inside a folder called as is it specified in the variable power_plants_raw_data_sources_folder_path.
#     <br>
#     All the downloaded files are named under the ordering of the download_links list.
#     <br>
#     Additionally, as some files use different kind of column delimiters e.g. ","; ";"; "/"; etc. the code verifies and changes this to be acceptable for the next steps
# </div>

# %%
#power_plants_raw_data_sources_file_path = "/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240418_185453/2023_power_plants_raw_data_sources_20240418_185453.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(power_plants_raw_data_sources_file_path)

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    download_link = row['Download_Link_Sources']
    file_name = str(row['File_Name'])  # Convert to string
    
    # Check if the download link is valid
    if pd.notnull(download_link) and pd.notnull(file_name):
        # Construct the destination file path
        destination_path = os.path.join(os.path.dirname(power_plants_raw_data_sources_file_path), file_name)
        
        # Copy the content from the download link to the destination file path
        shutil.copy(download_link, destination_path)
        print(f"File '{file_name}' copied successfully.")
    else:
        print("Download link or file name is missing.")
# Out:
# File '1' copied successfully.
# File '2' copied successfully.
# File '3' copied successfully.
# File '4' copied successfully.
# File '5' copied successfully.
# File '6' copied successfully.
# File '7' copied successfully.
# File '8' copied successfully.
# File '9' copied successfully.
# File '10' copied successfully.
# File '11' copied successfully.
# File '12' copied successfully.
# File '13' copied successfully.
# File '14' copied successfully.
# File '15' copied successfully.
# File '16' copied successfully.
# File '17' copied successfully.
# File '18' copied successfully.
# File '19' copied successfully.
# File '20' copied successfully.
# File '21' copied successfully.
# File '22' copied successfully.
# File '23' copied successfully.
# File '24' copied successfully.
# File '25' copied successfully.
# File '26' copied successfully.
# File '27' copied successfully.
# File '28' copied successfully.
# File '29' copied successfully.
# File '30' copied successfully.
# File '31' copied successfully.
# File '32' copied successfully.
# File '33' copied successfully.
# File '34' copied successfully.

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     5.2. Aditional Power Plants Raw Data
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Adding data of separate and syngle power units that are not included into the full downloaded raw data files.
# <br>
#     Introduce the 'Name', 'Power Capacity' and the 'Technology' of the units in the respective list.
# </div>
# <div style="text-align: left; margin-left: 2.0em; font-weight: unbold; font-size: 15px; font-family: TimesNewRoman;">
#     For the 'Techology' field match the current value of the added unit according with the following equivalences:
# </div>
# <div style="text-align: left; margin-left: 5.0em; font-weight: unbold; font-size: 10px; font-family: TimesNewRoman;">
#     Biomass
# <br>
#     Fossil Brown coal/Lignite
# <br>
#     Fossil Coal-derived gas
# <br>
#     Fossil Gas
# <br>
#     Fossil Hard coal
# <br>
#     Fossil Oil
# <br>
#     Fossil Oil shale
# <br>
#     Fossil Peat
# <br>
#     Geothermal
# <br>
#     Hydro Pumped Storage
# <br>
#     Hydro Run-of-river and poundage
# <br>
#     Hydro Water Reservoir
# <br>
#     Marine
# <br>
#     Nuclear
# <br>
#     Other renewable
# <br>
#     Solar
# <br>
#     Waste
# <br>
#     Wind Offshore
# <br>
#     Wind Onshore
# <br>
#     Other non-renewable
# </div>
# <div style="text-align: left; margin-left: 2.0em; font-weight: unbold; font-size: 15px; font-family: TimesNewRoman;">
# Additionally specify the European country acronym modelled by Dispa-SET which the corresponding unit belongs:
# </div>

# %%
name = ['Kristal _ Solar _ Park']
power_capacity = [99]
technology = ['Solar']
country = ['BE']

# %%
# Read the power plants raw data sources file
raw_data_sources = pd.read_csv(power_plants_raw_data_sources_file_path)

# Process each entry in the lists
for i, zone in enumerate(country):
    # Find the first occurrence of the zone in the raw data sources file
    match = raw_data_sources[raw_data_sources['Zone'] == zone].iloc[0]
    file_name = str(match['File_Name'])  # Ensure file_name is a string
    
    # Construct the path to the corresponding CSV file
    csv_file_path = os.path.join(os.path.dirname(power_plants_raw_data_sources_file_path), file_name)
    
    # Read the corresponding CSV file
    df = pd.read_csv(csv_file_path)
    
    # Create a new DataFrame with the new row
    new_row = pd.DataFrame({
        'Name': [name[i]],
        'Current Installed Capacity [MW]': [power_capacity[i]],
        'Intalled Capacity at the beginning of year [MW]': [power_capacity[i]],
        'Production Type': [technology[i]]
    })
    
    # Concatenate the new row to the DataFrame
    df = pd.concat([df, new_row], ignore_index=True)
    
    # Save the updated CSV file
    df.to_csv(csv_file_path, index=False)

print("CSV files updated successfully.")
# Out:
# CSV files updated successfully.

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     6. Zone Classification
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Filtering the data contained in each downloaded file accordingly the zone previously specified.
# </div>
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     6.1. Zone Definition
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Adding a new column under the name "Country" to each downloaded file which have been relationated with a key Zone in the list download_links_zone_related fulfilled previously
#     <br>
#     For all those files that have been set with the key "General", it is assumed that so file contains data from various zones, so It will be filtered in a different way.
# </div>

# %%
# Read the CSV file specified in power_plants_raw_data_sources_file_path
df_sources = pd.read_csv(power_plants_raw_data_sources_file_path)

# Iterate over each row in the DataFrame
for index, row in df_sources.iterrows():
    file_name = str(row['File_Name'])  # Convert to string
    zone = row['Zone']
    
    # Check if the zone is not "General"
    if zone != "General":
        # Construct the path to the corresponding CSV file
        csv_file_path = os.path.join(os.path.dirname(power_plants_raw_data_sources_file_path), file_name)
        
        # Check if the CSV file exists
        if os.path.exists(csv_file_path):
            # Read the CSV file
            df_csv = pd.read_csv(csv_file_path)
            
            # Add a new column "Country" with the value from the "Zone" column
            df_csv['Country'] = zone
            
            # Write the updated DataFrame back to the CSV file
            df_csv.to_csv(csv_file_path, index=False)
            
            print(f"Added 'Country' column to {file_name} with value '{zone}'")
        else:
            print(f"CSV file {file_name} does not exist.")
    else:
        print(f"No action needed for {file_name}")
# Out:
# Added 'Country' column to 1 with value 'AT'
# Added 'Country' column to 2 with value 'BE'
# Added 'Country' column to 3 with value 'BG'
# Added 'Country' column to 4 with value 'CH'
# Added 'Country' column to 5 with value 'CY'
# Added 'Country' column to 6 with value 'CZ'
# Added 'Country' column to 7 with value 'DE'
# Added 'Country' column to 8 with value 'DE'
# Added 'Country' column to 9 with value 'DE'
# Added 'Country' column to 10 with value 'DE'
# Added 'Country' column to 11 with value 'DK'
# Added 'Country' column to 12 with value 'EE'
# Added 'Country' column to 13 with value 'EL'
# Added 'Country' column to 14 with value 'ES'
# Added 'Country' column to 15 with value 'FI'
# Added 'Country' column to 16 with value 'FR'
# Added 'Country' column to 17 with value 'HR'
# Added 'Country' column to 18 with value 'HU'
# Added 'Country' column to 19 with value 'IE'
# Added 'Country' column to 20 with value 'IT'
# Added 'Country' column to 21 with value 'LT'
# Added 'Country' column to 22 with value 'LU'
# Added 'Country' column to 23 with value 'LV'
# Added 'Country' column to 24 with value 'MT'
# Added 'Country' column to 25 with value 'NL'
# Added 'Country' column to 26 with value 'NO'
# Added 'Country' column to 27 with value 'PL'
# Added 'Country' column to 28 with value 'PT'
# Added 'Country' column to 29 with value 'RO'
# Added 'Country' column to 30 with value 'SE'
# Added 'Country' column to 31 with value 'SI'
# Added 'Country' column to 32 with value 'SK'
# Added 'Country' column to 33 with value 'UK'
# Added 'Country' column to 34 with value 'UK'

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
print (f"dispaSET_unleash_folder_name: {dispaSET_unleash_folder_name}")
print (f"dispaSET_unleash_folder_path: {dispaSET_unleash_folder_path}")
print (f"power_plants_raw_data_folder_path: {power_plants_raw_data_folder_path}")
print (f"zone_names: {zone_names}")
print (f"created_zones: {created_zones}")
print (f"power_plants_raw_data_sources_file_path: {power_plants_raw_data_sources_file_path}")
print (f"power_plants_raw_data_sources_file_name: {power_plants_raw_data_sources_file_name}")
print (f"data_year: {data_year}")
print (f"download_links_zone_related: {download_links_zone_related}")
# Out:
# dispaSET_unleash_folder_name: Dispa-SET_Unleash
# dispaSET_unleash_folder_path: /home/ray/Dispa-SET_Unleash
# power_plants_raw_data_folder_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/
# zone_names: ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK']
# created_zones: {'AT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT', 'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE', 'BG': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG', 'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH', 'CY': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY', 'CZ': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ', 'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE', 'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK', 'EE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE', 'EL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL', 'ES': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES', 'FI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI', 'FR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR', 'HR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR', 'HU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU', 'IE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE', 'IT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT', 'LT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT', 'LU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU', 'LV': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV', 'MT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT', 'NL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL', 'NO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO', 'PL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL', 'PT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT', 'RO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO', 'SE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE', 'SI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI', 'SK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK', 'UK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'}
# power_plants_raw_data_sources_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240727_143238/2023_power_plants_raw_data_sources_20240727_143238.csv
# power_plants_raw_data_sources_file_name: 2023_power_plants_raw_data_sources_20240727_143238.csv
# data_year: 2023
# download_links_zone_related: ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DE', 'DE', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK', 'UK']

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     6.2. Raw Data File Zone Classification
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Moving each downloaded file to its corresponding folder zone accordinlgy the download_links_zone_related list.
#     <br>
#     The files relationed to the key "General" just will keep their current location.
# </div>

# %%
# Read the raw data sources file
df_sources = pd.read_csv(power_plants_raw_data_sources_file_path)

# Create a new column Final_File_Path
df_sources['Final_File_Path'] = ''

# Iterate over each row in the DataFrame
for index, row in df_sources.iterrows():
    file_name = str(row['File_Name'])
    file_path = os.path.join(os.path.dirname(power_plants_raw_data_sources_file_path), file_name)
    
    # Check if the file exists
    if os.path.exists(file_path):
        # Open and read the file
        df_csv = pd.read_csv(file_path)
        
        # Check if the file has the header 'Country'
        if 'Country' in df_csv.columns:
            # Get the corresponding value of 'Zone'
            zone_value = row['Zone']
            
            # Check if the zone folder exists
            if zone_value in zone_names:
                # Construct the destination folder path
                destination_folder = os.path.join(power_plants_raw_data_folder_path, zone_value)
                
                # Move the file to the destination folder
                destination_file_path = os.path.join(destination_folder, file_name)
                move(file_path, destination_file_path)
                print(f"Moved file '{file_name}' to '{destination_folder}'")
                
                # Get the current path of the moved file
                final_file_path = os.path.abspath(destination_file_path)
                df_sources.at[index, 'Final_File_Path'] = final_file_path
            else:
                print(f"Destination folder for zone '{zone_value}' does not exist.")
        else:
            print(f"No 'Country' header found in file '{file_name}'. No action needed.")
    else:
        print(f"File '{file_name}' does not exist.")
        
    # If file was not moved, update Final_File_Path with current path
    if not df_sources.at[index, 'Final_File_Path']:
        df_sources.at[index, 'Final_File_Path'] = os.path.abspath(file_path)

# Save the DataFrame back to the CSV file
df_sources.to_csv(power_plants_raw_data_sources_file_path, index=False)
# Out:
# Moved file '1' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT'
# Moved file '2' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE'
# Moved file '3' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG'
# Moved file '4' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH'
# Moved file '5' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY'
# Moved file '6' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ'
# Moved file '7' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE'
# Moved file '8' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE'
# Moved file '9' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE'
# Moved file '10' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE'
# Moved file '11' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK'
# Moved file '12' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE'
# Moved file '13' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL'
# Moved file '14' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES'
# Moved file '15' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI'
# Moved file '16' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR'
# Moved file '17' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR'
# Moved file '18' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU'
# Moved file '19' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE'
# Moved file '20' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT'
# Moved file '21' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT'
# Moved file '22' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU'
# Moved file '23' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV'
# Moved file '24' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT'
# Moved file '25' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL'
# Moved file '26' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO'
# Moved file '27' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL'
# Moved file '28' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT'
# Moved file '29' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO'
# Moved file '30' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE'
# Moved file '31' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI'
# Moved file '32' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK'
# Moved file '33' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'
# Moved file '34' to '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'

# %% [markdown]
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Extracting a list of all the path of the power plants raw data files.
#     <br>
#     This list is goning to be used as reference for future filtration stepts.
# </div>

# %%
# Read the CSV file
df = pd.read_csv(power_plants_raw_data_sources_file_path)

# Create the list power_plants_raw_data_file_list
power_plants_raw_data_file_list = []

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Convert integer values to string for File_Name and Final_File_Path
    file_name = str(row['File_Name'])
    final_file_path = str(row['Final_File_Path'])
    
    # Concatenate File_Name and Final_File_Path and append to the list
    file_path = os.path.join(file_name, final_file_path)
    power_plants_raw_data_file_list.append(file_path)

# Print the list
print(power_plants_raw_data_file_list)
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/1', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/3', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/4', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/5', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/6', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/7', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/8', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/9', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/10', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/11', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/12', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/13', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/14', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/15', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/16', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/17', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/18', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/19', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/20', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/21', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/22', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/23', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/24', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/25', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/26', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/27', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/28', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/29', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/30', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/31', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/32', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/33', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/34']

# %%
# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Extract the folder path
    folder_path = os.path.dirname(row['Final_File_Path'])
    
    # Update the DataFrame with the folder path
    df.at[index, 'Folder_Path'] = folder_path

# Save the DataFrame back to the CSV file
df.to_csv(power_plants_raw_data_sources_file_path, index=False)

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
print (f"dispaSET_unleash_folder_name: {dispaSET_unleash_folder_name}")
print (f"dispaSET_unleash_folder_path: {dispaSET_unleash_folder_path}")
print (f"power_plants_raw_data_folder_path: {power_plants_raw_data_folder_path}")
print (f"zone_names: {zone_names}")
print (f"created_zones: {created_zones}")
print (f"power_plants_raw_data_sources_file_path: {power_plants_raw_data_sources_file_path}")
print (f"power_plants_raw_data_sources_file_name: {power_plants_raw_data_sources_file_name}")
print (f"data_year: {data_year}")
print (f"download_links_zone_related: {download_links_zone_related}")
print (f"power_plants_raw_data_file_list: {power_plants_raw_data_file_list}")
# Out:
# dispaSET_unleash_folder_name: Dispa-SET_Unleash
# dispaSET_unleash_folder_path: /home/ray/Dispa-SET_Unleash
# power_plants_raw_data_folder_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/
# zone_names: ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK']
# created_zones: {'AT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT', 'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE', 'BG': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG', 'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH', 'CY': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY', 'CZ': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ', 'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE', 'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK', 'EE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE', 'EL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL', 'ES': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES', 'FI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI', 'FR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR', 'HR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR', 'HU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU', 'IE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE', 'IT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT', 'LT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT', 'LU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU', 'LV': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV', 'MT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT', 'NL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL', 'NO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO', 'PL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL', 'PT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT', 'RO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO', 'SE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE', 'SI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI', 'SK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK', 'UK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'}
# power_plants_raw_data_sources_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240727_143238/2023_power_plants_raw_data_sources_20240727_143238.csv
# power_plants_raw_data_sources_file_name: 2023_power_plants_raw_data_sources_20240727_143238.csv
# data_year: 2023
# download_links_zone_related: ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DE', 'DE', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK', 'UK']
# power_plants_raw_data_file_list: ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/1', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/3', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/4', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/5', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/6', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/7', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/8', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/9', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/10', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/11', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/12', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/13', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/14', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/15', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/16', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/17', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/18', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/19', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/20', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/21', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/22', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/23', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/24', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/25', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/26', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/27', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/28', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/29', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/30', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/31', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/32', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/33', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/34']

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
# 7. Data Formating
# </div>
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
# 7.1. Clean Data File Creation
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# Creating for each zone an empty csv file with all the technical features needed for Dispa-SET simulations as headers.
#     <br>
# This file will be named under the value of the variable data year previously specified.
#     <br>
# On this csv file all the filtered data in the following steps will be written.
# </div>

# %%
# Read the CSV file
df = pd.read_csv(power_plants_raw_data_sources_file_path)

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Get the folder path and file name
    folder_path = row['Folder_Path']
    file_name = f"{data_year}.csv"
    
    # Check if the file already exists in the folder
    file_path = os.path.join(folder_path, file_name)
    if os.path.exists(file_path):
        print(f"File '{file_name}' already exists in '{folder_path}'.")
        # Update the DataFrame with the existing file name and path
        df.at[index, 'Clean_File_Name'] = file_name
        df.at[index, 'Final_Clean_File_Path'] = file_path
    else:
        # Create the new CSV file with the specified headers
        headers = ["", "Unit", "PowerCapacity", "Nunits", "Zone", "Zone_th", "Zone_h2", "Technology", "Fuel", "Efficiency",
                   "MinUpTime", "MinDownTime", "RampUpRate", "RampDownRate", "StartUpCost", "NoLoadCost_pu", "RampingCost",
                   "PartLoadMin", "MinEfficiency", "StartUpTime", "CO2Intensity", "CHPType", "CHPPowerToHeat",
                   "CHPPowerLossFactor", "CHPMaxHeat", "COP", "Tnominal", "coef_COP_a", "coef_COP_b", "STOCapacity",
                   "STOSelfDischarge", "STOMaxChargingPower", "STOChargingEfficiency", "WaterWithdrawal", "WaterConsumption", "Status", "Source",
                   "Company", "Lat", "Lon"]
        with open(file_path, 'w') as f:
            f.write(','.join(headers))
        print(f"Created file '{file_name}' in '{folder_path}'.")
        # Update the DataFrame with the new file name and path
        df.at[index, 'Clean_File_Name'] = file_name
        df.at[index, 'Final_Clean_File_Path'] = file_path

# Create the list of clean data file paths
power_plants_clean_data_file_list = df['Final_Clean_File_Path'].tolist()

# Remove the header from the list
power_plants_clean_data_file_list.pop(0)

# Save the DataFrame back to the CSV file
df.to_csv(power_plants_raw_data_sources_file_path, index=False)
# Out:
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE'.
# File '2023.csv' already exists in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE'.
# File '2023.csv' already exists in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE'.
# File '2023.csv' already exists in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK'.
# Created file '2023.csv' in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'.
# File '2023.csv' already exists in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'.

# %%
# Read the CSV file
df = pd.read_csv(power_plants_raw_data_sources_file_path)

# Create the list power_plants_clean_data_file_list
power_plants_clean_data_file_list = []

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Convert integer values to string for File_Name and Final_Clean_File_Path
    file_name = str(row['File_Name'])
    final_file_path = str(row['Final_Clean_File_Path'])
    
    # Concatenate File_Name and Final_Clean_File_Path and append to the list
    file_path = os.path.join(file_name, final_file_path)
    power_plants_clean_data_file_list.append(file_path)

# Print the list
print(power_plants_clean_data_file_list)
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
print (f"dispaSET_unleash_folder_name: {dispaSET_unleash_folder_name}")
print (f"dispaSET_unleash_folder_path: {dispaSET_unleash_folder_path}")
print (f"power_plants_raw_data_folder_path: {power_plants_raw_data_folder_path}")
print (f"zone_names: {zone_names}")
print (f"created_zones: {created_zones}")
print (f"power_plants_raw_data_sources_file_path: {power_plants_raw_data_sources_file_path}")
print (f"power_plants_raw_data_sources_file_name: {power_plants_raw_data_sources_file_name}")
print (f"data_year: {data_year}")
print (f"download_links_zone_related: {download_links_zone_related}")
print (f"power_plants_raw_data_file_list: {power_plants_raw_data_file_list}")
print (f"power_plants_clean_data_file_list: {power_plants_clean_data_file_list}")
# Out:
# dispaSET_unleash_folder_name: Dispa-SET_Unleash
# dispaSET_unleash_folder_path: /home/ray/Dispa-SET_Unleash
# power_plants_raw_data_folder_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/
# zone_names: ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK']
# created_zones: {'AT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT', 'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE', 'BG': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG', 'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH', 'CY': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY', 'CZ': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ', 'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE', 'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK', 'EE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE', 'EL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL', 'ES': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES', 'FI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI', 'FR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR', 'HR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR', 'HU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU', 'IE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE', 'IT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT', 'LT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT', 'LU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU', 'LV': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV', 'MT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT', 'NL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL', 'NO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO', 'PL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL', 'PT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT', 'RO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO', 'SE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE', 'SI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI', 'SK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK', 'UK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'}
# power_plants_raw_data_sources_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240727_143238/2023_power_plants_raw_data_sources_20240727_143238.csv
# power_plants_raw_data_sources_file_name: 2023_power_plants_raw_data_sources_20240727_143238.csv
# data_year: 2023
# download_links_zone_related: ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DE', 'DE', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK', 'UK']
# power_plants_raw_data_file_list: ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/1', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/3', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/4', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/5', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/6', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/7', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/8', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/9', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/10', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/11', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/12', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/13', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/14', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/15', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/16', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/17', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/18', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/19', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/20', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/21', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/22', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/23', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/24', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/25', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/26', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/27', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/28', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/29', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/30', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/31', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/32', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/33', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/34']
# power_plants_clean_data_file_list: ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     7.2. Dictionary Files
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Getting the current paths of all the dictionary files that are going to be used as reference for the next filtering data process.
#         <br>
#     The dictionady files are .csv files that contain a small data base of al the technical denomination ussually used for the power units, e.g. 'PowerCapacity', 'Energy Source", 'Technology' etc.
# </div>

# %%
#dispaSET_unleash_folder_path = "/home/ray/Dispa-SET_Unleash"  # Replace with your actual path

# List of file names
file_names = [
    "ENTSOE_Production_Type.csv",
    "power_plants_clean_data_equivalent_headers.csv",
    "power_plants_all_data_equivalent_technologies.csv",
    "power_plants_all_data_equivalent_fuels.csv",
    "power_plants_all_data_equivalent_CHPTypes.csv",
    "EU_Power_Units_Technical_Features.csv"
]

# Dictionary to store file paths
file_paths = {}

# Construct file paths
for file_name in file_names:
    # Construct the file path
    file_path = os.path.join(dispaSET_unleash_folder_path, "RawData", "PowerPlants", "Dictionaries", file_name)

    # Store the file path in the dictionary
    file_paths[file_name] = file_path

# Define variables explicitly using the file paths
EU_Power_Units_Technical_Features_file_path = file_paths["EU_Power_Units_Technical_Features.csv"]
power_plants_clean_data_equivalent_headers_file_path = file_paths["power_plants_clean_data_equivalent_headers.csv"]
power_plants_all_data_equivalent_technologies_file_path = file_paths["power_plants_all_data_equivalent_technologies.csv"]
power_plants_all_data_equivalent_fuels_file_path = file_paths["power_plants_all_data_equivalent_fuels.csv"]
power_plants_all_data_equivalent_CHPTypes_file_path = file_paths["power_plants_all_data_equivalent_CHPTypes.csv"]
ENTSOE_Production_Type_file_path = file_paths["ENTSOE_Production_Type.csv"]
# ... Define other variables similarly using file_paths dictionary

# The variables are now accessible throughout your code.

# Print the variables (optional)
for file_name, file_path in file_paths.items():
     print(f"{file_name.split('.')[0]}_file_path: {file_path}")
# Out:
# ENTSOE_Production_Type_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/ENTSOE_Production_Type.csv
# power_plants_clean_data_equivalent_headers_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_clean_data_equivalent_headers.csv
# power_plants_all_data_equivalent_technologies_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_technologies.csv
# power_plants_all_data_equivalent_fuels_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_fuels.csv
# power_plants_all_data_equivalent_CHPTypes_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_CHPTypes.csv
# EU_Power_Units_Technical_Features_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/EU_Power_Units_Technical_Features.csv

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
print (f"dispaSET_unleash_folder_name: {dispaSET_unleash_folder_name}")
print (f"dispaSET_unleash_folder_path: {dispaSET_unleash_folder_path}")
print (f"power_plants_raw_data_folder_path: {power_plants_raw_data_folder_path}")
print (f"zone_names: {zone_names}")
print (f"created_zones: {created_zones}")
print (f"power_plants_raw_data_sources_file_path: {power_plants_raw_data_sources_file_path}")
print (f"power_plants_raw_data_sources_file_name: {power_plants_raw_data_sources_file_name}")
print (f"data_year: {data_year}")
print (f"download_links_zone_related: {download_links_zone_related}")
print (f"power_plants_raw_data_file_list: {power_plants_raw_data_file_list}")
print (f"power_plants_clean_data_file_list: {power_plants_clean_data_file_list}")
print (f"power_plants_clean_data_equivalent_headers_file_path: {power_plants_clean_data_equivalent_headers_file_path}")
print (f"power_plants_all_data_equivalent_technologies_file_path: {power_plants_all_data_equivalent_technologies_file_path}")
print (f"power_plants_all_data_equivalent_fuels_file_path: {power_plants_all_data_equivalent_fuels_file_path}")
print (f"power_plants_all_data_equivalent_CHPTypes_file_path: {power_plants_all_data_equivalent_CHPTypes_file_path}")
print (f"EU_Power_Units_Technical_Features_file_path: {EU_Power_Units_Technical_Features_file_path}")
print (f"ENTSOE_Production_Type_file_path: {ENTSOE_Production_Type_file_path}")
# Out:
# dispaSET_unleash_folder_name: Dispa-SET_Unleash
# dispaSET_unleash_folder_path: /home/ray/Dispa-SET_Unleash
# power_plants_raw_data_folder_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/
# zone_names: ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK']
# created_zones: {'AT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT', 'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE', 'BG': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG', 'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH', 'CY': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY', 'CZ': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ', 'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE', 'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK', 'EE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE', 'EL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL', 'ES': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES', 'FI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI', 'FR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR', 'HR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR', 'HU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU', 'IE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE', 'IT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT', 'LT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT', 'LU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU', 'LV': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV', 'MT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT', 'NL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL', 'NO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO', 'PL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL', 'PT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT', 'RO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO', 'SE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE', 'SI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI', 'SK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK', 'UK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'}
# power_plants_raw_data_sources_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240727_143238/2023_power_plants_raw_data_sources_20240727_143238.csv
# power_plants_raw_data_sources_file_name: 2023_power_plants_raw_data_sources_20240727_143238.csv
# data_year: 2023
# download_links_zone_related: ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DE', 'DE', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK', 'UK']
# power_plants_raw_data_file_list: ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/1', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/3', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/4', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/5', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/6', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/7', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/8', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/9', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/10', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/11', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/12', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/13', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/14', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/15', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/16', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/17', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/18', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/19', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/20', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/21', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/22', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/23', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/24', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/25', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/26', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/27', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/28', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/29', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/30', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/31', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/32', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/33', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/34']
# power_plants_clean_data_file_list: ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']
# power_plants_clean_data_equivalent_headers_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_clean_data_equivalent_headers.csv
# power_plants_all_data_equivalent_technologies_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_technologies.csv
# power_plants_all_data_equivalent_fuels_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_fuels.csv
# power_plants_all_data_equivalent_CHPTypes_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_CHPTypes.csv
# EU_Power_Units_Technical_Features_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/EU_Power_Units_Technical_Features.csv
# ENTSOE_Production_Type_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/ENTSOE_Production_Type.csv

# %%
power_plants_clean_data_file_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     7.3. ENTSOE SOURCE FILES DATA PRODUCTION TECHNOLOGY TYPE
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Getting the technology and fuel clasification for all the raw data from ENTSO-E source.
#         <br>
#     Since all the data obtained from ENTSO-E web portal does not make a classification of generation technology and fuel source, it is going to use the dictionary called "ENTSO-E_Production_Type.csv" where all the equivalent technologies and fuels are going to be extracted accoding the "Production Type" classification used by ENTSO-E.
# </div>

# %%
# Read the CSV files
#power_plants_file_path = "/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240507_132711/2023_power_plants_raw_data_sources_20240507_132711.csv"
#entsoe_production_type_file_path = "/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ENTSOE_Production_Type.csv"

power_plants_df = pd.read_csv(power_plants_raw_data_sources_file_path)
entsoe_production_type_df = pd.read_csv(ENTSOE_Production_Type_file_path)

# Function to process each text file
def process_text_file(text_file_path):
    # Read the text file
    with open(text_file_path, 'r') as file:
        lines = file.readlines()

    # Check if 'Production Type' column exists
    header = lines[0].strip().split(',')
    if 'Production Type' in header:
        # Add 'Technology' and 'Fuel' columns if not present
        if 'Technology' not in header:
            header.extend(['Technology', 'Fuel'])
            lines[0] = ','.join(header) + '\n'

        # Extract 'Production Type' column index
        production_type_index = header.index('Production Type')

        # Process each row in the text file
        for i in range(1, len(lines)):
            fields = lines[i].strip().split(',')
            production_type = fields[production_type_index]

            # Find corresponding technology and fuel
            match_row = entsoe_production_type_df[entsoe_production_type_df['Complete Term'] == production_type]
            if not match_row.empty:
                technology = match_row['technology'].values[0]
                fuel = match_row['fuel'].values[0]
                fields.extend([technology, fuel])
                lines[i] = ','.join(fields) + '\n'

        # Write back to the text file
        with open(text_file_path, 'w') as file:
            file.writelines(lines)
        
        # Print message when the file is done
        print(f"Processed {text_file_path}")

# Process each row in power_plants_df
for index, row in power_plants_df.iterrows():
    text_file_path = row['Final_File_Path']
    if os.path.exists(text_file_path):
        process_text_file(text_file_path)
# Out:
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/1
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/3
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/4
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/5
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/6
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/7
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/8
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/9
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/10
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/11
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/12
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/13
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/14
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/15
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/16
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/17
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/18
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/19
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/20
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/21
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/22
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/23
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/24
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/25
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/26
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/27
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/28
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/29
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/30
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/31
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/32
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/33
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/34

# %% [markdown]
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Copying all the needed columns from the raw data files to the clean data files in base to the order given by the lists power_plants_raw_data_file_list and power_plants_clean_data_file_list.
#         <br>
#     This processes is made to each zone calling the function copy_columns_to_clean_data.py
# </div>

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
power_plants_raw_data_file_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/1',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/3',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/4',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/5',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/6',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/7',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/8',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/9',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/10',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/11',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/12',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/13',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/14',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/15',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/16',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/17',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/18',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/19',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/20',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/21',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/22',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/23',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/24',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/25',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/26',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/27',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/28',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/29',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/30',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/31',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/32',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/33',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/34']

# %%
power_plants_clean_data_file_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %%
from copy_columns_to_clean_data import copy_columns_to_clean_data
# Iterate over each pair of files
for raw_data_file, clean_data_file in zip(power_plants_raw_data_file_list, power_plants_clean_data_file_list):
    # Call the function with appropriate arguments
    copy_columns_to_clean_data(raw_data_file, clean_data_file, power_plants_clean_data_equivalent_headers_file_path)
# Out:
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# Columns copied successfully.
# Columns copied successfully.
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/copy_columns_to_clean_data.py:43: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clean_data_df = pd.concat([clean_data_df, new_rows], ignore_index=True)
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.
# Columns copied successfully.

# %% [markdown]
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# Readdapting the power_plant_clean_file_list variable.
# </div>

# %%
# Function to remove duplicates while preserving order
def remove_duplicates_preserve_order(file_list):
    seen = set()
    unique_list = []
    for item in file_list:
        if item not in seen:
            unique_list.append(item)
            seen.add(item)
    return unique_list

# Remove duplicates
unique_power_plants_clean_data_file_list = remove_duplicates_preserve_order(power_plants_clean_data_file_list)

# Print the unique list to verify
print(unique_power_plants_clean_data_file_list)
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %%
power_plants_clean_data_file_list = unique_power_plants_clean_data_file_list
power_plants_clean_data_file_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     7.5. Units Name Field Fulfill
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Verifying the "Unit" field in all the rows of each cleand data file.
#         <br>
#      If there is no value, the corresponding latitud and longitud value is going to be used as identifier of the corresponding unit.
#         <br>
#     If there is no value in the latitud and longitud fields the corresponding "Company" data is going to be taken.
#     <br>
#     Finally if there is not any company related data, the "Unit" field is going to be performed form the zone name plus an increasing numner.
#         <br>
#     This processes is made to each zone calling the function units_name_fulfilling.py
# </div>

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
power_plants_clean_data_file_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %%
from Data_Processing_Functions import fill_unit_field

# List of file paths
#power_plants_clean_data_file_list = ['path_to_file1.csv', 'path_to_file2.csv', 'path_to_file3.csv']

# Iterate over each file path
for file_path in power_plants_clean_data_file_list:
    fill_unit_field(file_path)
# Out:
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.
# Unit field filled successfully.

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     7.6. Nunits Field Fulfill
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Verifying the "Nunit" field in all the rows of each cleand data file.
#         <br>
#      If there is no value, the field is gonna be filled by 1.
#         <br>
#     This processes is made for each zone calling the function fill_nunits_column.py
# </div>

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
power_plants_clean_data_file_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %%
from Data_Processing_Functions import fill_nunits_column

# List of file paths
#clean_data_file_paths = ["path/to/your/clean_data1.csv", "path/to/your/clean_data2.csv", ...]

# Apply the function to each file
for file_path in power_plants_clean_data_file_list:
    fill_nunits_column(file_path)
# Out:
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.
# Nunits column processed successfully.

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     7.7. Zone Field Filter
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Verifying the "Zone" field in all the rows of each cleand data file.
#         <br>
#      If there is no value, the field is gonna be took out from the file.
#     <br>
#      Additionally all the eliminated rows are going to be storage in a csv file called power_plants_all_data_not_defined_units.
#         <br>
#     This processes is made for each zone calling the function units_name_filter.py
# </div>

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
print (f"dispaSET_unleash_folder_name: {dispaSET_unleash_folder_name}")
print (f"dispaSET_unleash_folder_path: {dispaSET_unleash_folder_path}")
print (f"power_plants_raw_data_folder_path: {power_plants_raw_data_folder_path}")
print (f"zone_names: {zone_names}")
print (f"created_zones: {created_zones}")
print (f"power_plants_raw_data_sources_file_path: {power_plants_raw_data_sources_file_path}")
print (f"power_plants_raw_data_sources_file_name: {power_plants_raw_data_sources_file_name}")
print (f"data_year: {data_year}")
print (f"download_links_zone_related: {download_links_zone_related}")
print (f"power_plants_raw_data_file_list: {power_plants_raw_data_file_list}")
print (f"power_plants_clean_data_file_list: {power_plants_clean_data_file_list}")
print (f"power_plants_clean_data_equivalent_headers_file_path: {power_plants_clean_data_equivalent_headers_file_path}")
print (f"power_plants_all_data_equivalent_technologies_file_path: {power_plants_all_data_equivalent_technologies_file_path}")
print (f"power_plants_all_data_equivalent_fuels_file_path: {power_plants_all_data_equivalent_fuels_file_path}")
print (f"power_plants_all_data_equivalent_CHPTypes_file_path: {power_plants_all_data_equivalent_CHPTypes_file_path}")
print (f"EU_Power_Units_Technical_Features_file_path: {EU_Power_Units_Technical_Features_file_path}")
# Out:
# dispaSET_unleash_folder_name: Dispa-SET_Unleash
# dispaSET_unleash_folder_path: /home/ray/Dispa-SET_Unleash
# power_plants_raw_data_folder_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/
# zone_names: ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK']
# created_zones: {'AT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT', 'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE', 'BG': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG', 'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH', 'CY': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY', 'CZ': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ', 'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE', 'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK', 'EE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE', 'EL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL', 'ES': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES', 'FI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI', 'FR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR', 'HR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR', 'HU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU', 'IE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE', 'IT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT', 'LT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT', 'LU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU', 'LV': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV', 'MT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT', 'NL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL', 'NO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO', 'PL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL', 'PT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT', 'RO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO', 'SE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE', 'SI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI', 'SK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK', 'UK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'}
# power_plants_raw_data_sources_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240727_143238/2023_power_plants_raw_data_sources_20240727_143238.csv
# power_plants_raw_data_sources_file_name: 2023_power_plants_raw_data_sources_20240727_143238.csv
# data_year: 2023
# download_links_zone_related: ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DE', 'DE', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK', 'UK']
# power_plants_raw_data_file_list: ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/1', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/3', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/4', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/5', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/6', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/7', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/8', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/9', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/10', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/11', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/12', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/13', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/14', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/15', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/16', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/17', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/18', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/19', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/20', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/21', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/22', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/23', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/24', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/25', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/26', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/27', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/28', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/29', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/30', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/31', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/32', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/33', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/34']
# power_plants_clean_data_file_list: ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']
# power_plants_clean_data_equivalent_headers_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_clean_data_equivalent_headers.csv
# power_plants_all_data_equivalent_technologies_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_technologies.csv
# power_plants_all_data_equivalent_fuels_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_fuels.csv
# power_plants_all_data_equivalent_CHPTypes_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_CHPTypes.csv
# EU_Power_Units_Technical_Features_file_path: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/EU_Power_Units_Technical_Features.csv

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 16px; font-family: TimesNewRoman;">
#     7.7.1. Not Defined Units File Creation
# </div>
#
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Creating a .csv file for each zone where all those units that has some missing data in one of their field are going to be written such as all the units that are took out from the final clean data file for some other reason.
#
# </div>

# %%
# Function to create the CSV file with specified headers
def create_csv_file(file_path, headers):
    with open(file_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(headers)

# Define the headers for the CSV file
headers = ["", "Unit", "PowerCapacity", "Nunits", "Zone", "Zone_th", "Zone_h2", "Technology", "Fuel", "Efficiency",
           "MinUpTime", "MinDownTime", "RampUpRate", "RampDownRate", "StartUpCost", "NoLoadCost_pu", "RampingCost",
           "PartLoadMin", "MinEfficiency", "StartUpTime", "CO2Intensity", "CHPType", "CHPPowerToHeat",
           "CHPPowerLossFactor", "CHPMaxHeat", "COP", "Tnominal", "coef_COP_a", "coef_COP_b", "STOCapacity",
           "STOSelfDischarge", "STOMaxChargingPower", "STOChargingEfficiency", "WaterWithdrawal", "WaterConsumption", "Status", "Source",
           "Company", "Lat", "Lon"]

# List to store the paths of created CSV files
power_plants_all_data_not_defined_units_file_list = []

# Read the CSV file and create CSV files in each folder path
with open(power_plants_raw_data_sources_file_path, 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        folder_path = row['Folder_Path']
        file_name = 'power_plants_all_data_not_defined_units.csv'
        file_path = os.path.join(folder_path, file_name)
        create_csv_file(file_path, headers)
        print(f"CSV file created at {file_path}")
        power_plants_all_data_not_defined_units_file_list.append(file_path)

print("All CSV files created successfully.")
# Out:
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/power_plants_all_data_not_defined_units.csv
# CSV file created at /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/power_plants_all_data_not_defined_units.csv
# All CSV files created successfully.

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 16px; font-family: TimesNewRoman;">
#     7.7.2. No Data Zone Field Elimination
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Eliminating all the data that does not have a zone, country, region etc. in its Zone field.
# </div>

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
power_plants_all_data_not_defined_units_file_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/power_plants_all_data_not_defined_units.csv']

# %%
power_plants_clean_data_file_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %%
from Data_Processing_Functions import move_rows_with_empty_zone

# Iterate over each pair of files
for clean_data_file, all_data_file in zip(power_plants_clean_data_file_list, power_plants_all_data_not_defined_units_file_list):
    # Call the function with appropriate arguments
    move_rows_with_empty_zone([clean_data_file], [all_data_file])
# Out:
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv
# Processed /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     7.8. Technology Field Filter
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Re-naming the current value of all the fileds of Technology column.
#     <br>
#     Since the generation technology name of the power units may not be homogeneous among all data sources. The current value of this field is compared with the technology equivalence dictionary database to obtain the one corresponding to the Dispa-SET format.
#         <br>
#     Additionally all the rows which Technolgy field have not been matched with any equivalency are going to be took out fron the cleand data file and added to the not defined units data list.
#     <br>
#     This process is done for each zone.
# </div>

# %% [markdown]
# <div style="text-align: right; margin-left: 3.0em; font-weight: unbold; font-size: 14px; font-family: TimesNewRoman;">
#     Tracking Variables.
#     <br>
#     <div style="text-align: right; margin-left: 1.50em; font-weight: unbold; font-size: 13px; font-family: TimesNewRoman;">
#     This cells are just to confirm all the file names, file paths and other information related to the data being processed.
#     <br>
#   Also are used to ensure the inputs for next cells in order to avoid to re-enter the same information each time.
# </div>

# %%
print (f"dispaSET_unleash_folder_name:                                {dispaSET_unleash_folder_name}")
print (f"dispaSET_unleash_folder_path:                                {dispaSET_unleash_folder_path}")
print (f"power_plants_raw_data_folder_path:                           {power_plants_raw_data_folder_path}")
print (f"zone_names:                                                  {zone_names}")
print (f"created_zones:                                               {created_zones}")
print (f"power_plants_raw_data_sources_file_path:                     {power_plants_raw_data_sources_file_path}")
print (f"power_plants_raw_data_sources_file_name:                     {power_plants_raw_data_sources_file_name}")
print (f"data_year:                                                   {data_year}")
print (f"download_links_zone_related:                                 {download_links_zone_related}")
print (f"power_plants_raw_data_file_list:                             {power_plants_raw_data_file_list}")
print (f"power_plants_clean_data_file_list:                           {power_plants_clean_data_file_list}")
print (f"power_plants_clean_data_equivalent_headers_file_path:        {power_plants_clean_data_equivalent_headers_file_path}")
print (f"power_plants_all_data_equivalent_technologies_file_path:     {power_plants_all_data_equivalent_technologies_file_path}")
print (f"power_plants_all_data_equivalent_fuels_file_path:            {power_plants_all_data_equivalent_fuels_file_path}")
print (f"power_plants_all_data_equivalent_CHPTypes_file_path:         {power_plants_all_data_equivalent_CHPTypes_file_path}")
print (f"EU_Power_Units_Technical_Features_file_path:                 {EU_Power_Units_Technical_Features_file_path}")
print (f"power_plants_raw_data_file_list:                             {power_plants_raw_data_file_list}")
print (f"power_plants_all_data_not_defined_units_file_list:           {power_plants_all_data_not_defined_units_file_list}")
# Out:
# dispaSET_unleash_folder_name:                                Dispa-SET_Unleash
# dispaSET_unleash_folder_path:                                /home/ray/Dispa-SET_Unleash
# power_plants_raw_data_folder_path:                           /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/
# zone_names:                                                  ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK']
# created_zones:                                               {'AT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT', 'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE', 'BG': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG', 'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH', 'CY': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY', 'CZ': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ', 'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE', 'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK', 'EE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE', 'EL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL', 'ES': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES', 'FI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI', 'FR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR', 'HR': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR', 'HU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU', 'IE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE', 'IT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT', 'LT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT', 'LU': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU', 'LV': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV', 'MT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT', 'NL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL', 'NO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO', 'PL': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL', 'PT': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT', 'RO': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO', 'SE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE', 'SI': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI', 'SK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK', 'UK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK'}
# power_plants_raw_data_sources_file_path:                     /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240727_143238/2023_power_plants_raw_data_sources_20240727_143238.csv
# power_plants_raw_data_sources_file_name:                     2023_power_plants_raw_data_sources_20240727_143238.csv
# data_year:                                                   2023
# download_links_zone_related:                                 ['AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DE', 'DE', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK', 'UK', 'UK']
# power_plants_raw_data_file_list:                             ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/1', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/3', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/4', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/5', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/6', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/7', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/8', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/9', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/10', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/11', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/12', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/13', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/14', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/15', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/16', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/17', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/18', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/19', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/20', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/21', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/22', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/23', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/24', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/25', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/26', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/27', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/28', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/29', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/30', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/31', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/32', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/33', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/34']
# power_plants_clean_data_file_list:                           ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']
# power_plants_clean_data_equivalent_headers_file_path:        /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_clean_data_equivalent_headers.csv
# power_plants_all_data_equivalent_technologies_file_path:     /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_technologies.csv
# power_plants_all_data_equivalent_fuels_file_path:            /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_fuels.csv
# power_plants_all_data_equivalent_CHPTypes_file_path:         /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/power_plants_all_data_equivalent_CHPTypes.csv
# EU_Power_Units_Technical_Features_file_path:                 /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/EU_Power_Units_Technical_Features.csv
# power_plants_raw_data_file_list:                             ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/1', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/3', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/4', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/5', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/6', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/7', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/8', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/9', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/10', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/11', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/12', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/13', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/14', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/15', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/16', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/17', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/18', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/19', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/20', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/21', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/22', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/23', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/24', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/25', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/26', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/27', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/28', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/29', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/30', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/31', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/32', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/33', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/34']
# power_plants_all_data_not_defined_units_file_list:           ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/power_plants_all_data_not_defined_units.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/power_plants_all_data_not_defined_units.csv']

# %%
from Data_Processing_Functions import update_technology_equivalents

# Iterate over each pair of files
for clean_data_file, not_defined_units_file in zip(power_plants_clean_data_file_list, power_plants_all_data_not_defined_units_file_list):
    # Call the function with appropriate arguments
    update_technology_equivalents(clean_data_file, power_plants_all_data_equivalent_technologies_file_path, not_defined_units_file)
# Out:
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.
# Technology equivalents updated successfully.

# %%
power_plants_clean_data_file_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %%
power_plants_all_data_not_defined_units_file_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/power_plants_all_data_not_defined_units.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/power_plants_all_data_not_defined_units.csv']

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     7.9. Fuel Field Filter
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Re-naming the current value of all the fields of Fuel column.
#     <br>
#     Since the fuel sources names of the power units may not be homogeneous among all data sources. The current value of this field is compared with the fuel equivalence dictionary database to obtain the one corresponding to the Dispa-SET format.
#         <br>
#     Additionally all the rows which Fuel field have not been matched with any equivalency are going to be took out fron the cleand data file and added to the not defined units data list.
#     <br>
#     This process is done for each zone.
# </div>

# %%
from Data_Processing_Functions import update_fuel_equivalents

# Iterate over each pair of files
for clean_data_file_path, not_defined_units_file_path in zip(power_plants_clean_data_file_list, power_plants_all_data_not_defined_units_file_list):
    # Call the function with appropriate arguments
    update_fuel_equivalents(clean_data_file_path, power_plants_all_data_equivalent_fuels_file_path, not_defined_units_file_path)
# Out:
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.
# Fuel equivalents updated successfully.

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     7.10. CHPType, CHPPowerToHeat, CHPPowerLossFactor and CHPMaxHeat Fields Filter
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Re-naming the current value of all the fields of CHPType column.
#     <br>
#     Since the fuel sources names of the power units may not be homogeneous among all data sources. The current value of CHPType field is compared with the CHP equivalence dictionary database to obtain the one corresponding to the Dispa-SET format.
#         <br>
#     This part reads for each unit the current value of the column called "CHPMaxHeat" of power_plants_clean_data file. If the unit has any value on this field,  checks out its respective value in the column CHPType, and compares wiht the table power_plants_all_data_equivalent_CHPTypes_file, if there is no coincydense, copies the row to the power_plants_all_data_not_defined_units_file leaving this field empty, but keeping the information of the other related fields.
#      <br>
#     This process is done for each zone.
# </div>

# %%
from Data_Processing_Functions import update_chp_types

# Iterate over each pair of files
for clean_data_file_path, not_defined_units_file_path in zip(power_plants_clean_data_file_list, power_plants_all_data_not_defined_units_file_list):
    # Call the function with appropriate arguments
    update_chp_types(clean_data_file_path, power_plants_all_data_equivalent_CHPTypes_file_path, not_defined_units_file_path)
# Out:
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.
# CHP types updated successfully.

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     7.11. Power Capacity Field Filter
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Erasing all the units with the Power Capacity field empty or with zero value.
#          <br>
#     This process is done for each zone.
# </div>

# %%
from Data_Processing_Functions import remove_zero_power_capacity

# Iterate over each pair of files
for clean_data_file_path, not_defined_units_file_path in zip(power_plants_clean_data_file_list, power_plants_all_data_not_defined_units_file_list):
    # Call the function with appropriate arguments
    remove_zero_power_capacity(clean_data_file_path, not_defined_units_file_path)
# Out:
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.
# Zero power capacity rows removed successfully.

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     7.12. Efficiency Field Fullfilling
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Finding the closest efficiency value for all the units with the Efficiency field empty or with zero value.
#     <br>
#     The Efficiency technical feauture is taken from the already agregated data base EU_Power_Units_Technical_Features.csv using the notebook: EU_Power_Plant_Technical_Data_Base_Gathering.ipynb and is os sellected in base on the Technology, the Fuel and the PowerCapacity features.
#      <br>
#     This process is done for each zone.
# </div>

# %%
power_plants_clean_data_file_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %%
EU_Power_Units_Technical_Features_file_path
# Out:
# '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/Dictionaries/EU_Power_Units_Technical_Features.csv'

# %%
# Import the function from the external script
from Data_Processing_Functions import copy_technical_values

# Define the paths and variables
#EU_Power_Units_Technical_Features_file_path = '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EU_Power_Units_Technical_Features.csv'
#power_plants_clean_data_file_list = [
#    '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2020_power_plants_raw_data_sources_20240407_172323/2020.csv',
#    '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2020.csv',
#    '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2020.csv',
#    '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2020.csv'
#]
common_columns = ['PowerCapacity', 'Technology', 'Fuel']
column_to_copy = 'Efficiency'

copy_technical_values(EU_Power_Units_Technical_Features_file_path, power_plants_clean_data_file_list, common_columns, column_to_copy)
# Out:
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv
# Efficiency Field values copied successfully.

# %% [markdown]
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Filling with a value of 1 the efficiency technical feature for all the units with the Efficiency field empty or with zero value.
#     <br>
#     Additionally all this units found with any efficiency value, will be copied to the corresponding no denined units file.
#      <br>
#     This process is done for each zone.
# </div

# %%
from Data_Processing_Functions import fill_empty_values_with_specified

# Define the columns to be filled
Column = 'Efficiency'
Value = '1'  # Change this to the desired value

# Iterate over each pair of files
for input_file, output_file in zip(power_plants_clean_data_file_list, power_plants_all_data_not_defined_units_file_list):
    # Call the function for the current pair of files
    fill_empty_values_with_specified(input_file, output_file, Column, Value)
# Out:
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv'.
# No empty 'Efficiency' or value 0 cells found in '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv'.

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     7.13.  MinDownTime | MinDownTime | RampUpRate | RampDownRate | StartUpCost | NoLoadCost_pu | RampingCost | PartLoadMin | MinEfficiency | StartUpTime | CO2Intensity Fields Fulfilling
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Finding the closest value for the next technical features:
#     <br>
#     MinUpTime, MinDownTime, MinDownTime, RampUpRate, RampDownRate, StartUpCost, NoLoadCost_pu, RampingCost, PartLoadMin, MinEfficiency, StartUpTime, CO2Intensity.
#     <br>
#     This is done for all the units which corresponding field value is empty or with zero.
#     <br>
#     All the technical feautures are taken from the already agregated data base EU_Power_Units_Technical_Features.csv using the notebook: EU_Power_Plant_Technical_Data_Base_Gathering.ipynb and are sellected in base on the Technology, the Fuel and the PowerCapacity features.
#      <br>
#     This process is done for each zone.
# </div>

# %%
columns_to_copy = [
    'MinUpTime',
    'MinDownTime',
    'RampUpRate',
    'RampDownRate',
    'StartUpCost',
    'NoLoadCost_pu',
    'RampingCost',
    'PartLoadMin',
    'MinEfficiency',
    'StartUpTime',
    'CO2Intensity'
]
common_columns = ['PowerCapacity', 'Technology', 'Fuel']

# %%
for column_to_copy in columns_to_copy:
    copy_technical_values(EU_Power_Units_Technical_Features_file_path, power_plants_clean_data_file_list, common_columns, column_to_copy)
# Out:
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# MinUpTime Field values copied successfully.
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# /home/ray/Dispa-SET_Unleash/scripts/Data_Processing/Data_Processing_Functions.py:584: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_fuel_filtered['PowerCapacity'] = pd.to_numeric(first_fuel_filtered['PowerCapacity'], errors='coerce')
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv
# Processing target file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv
# CO2Intensity Field values copied successfully.

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     8. Zone Final Classification
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Filtering by Zone all the formating files resulting from the downloads files set by the "General" key at the begining of the process.
#     <br>
#     Each row of the files are copied according their zone clasification in their corresponding folder path.
# </div>
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     8.1. Zone Field Homogenization
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Eliminating the space characters from the Zone fileds to avoid errors in the zone classifiaction process.
#     <br>
#     This process is done for each zone.
# </div>

# %%
# List of file paths
#power_plants_clean_data_file_list = [
#    '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2020_power_plants_raw_data_sources_20240407_201458/2020.csv',
#    '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2020.csv',
#    '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2020.csv',
#    '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2020.csv'
#]

# Iterate over each file
for file_path in power_plants_clean_data_file_list:
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Trim values in the 'Zone' column
    if 'Zone' in df.columns:
        df['Zone'] = df['Zone'].str.strip()

        # Write the modified DataFrame back to the CSV file
        df.to_csv(file_path, index=False)

        print(f"Trimmed 'Zone' column values in {file_path}")
    else:
        print(f"'Zone' column not found in {file_path}")
# Out:
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv
# Trimmed 'Zone' column values in /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv

# %% [markdown]
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Filtering by Zone all the formating files resulting from the downloads files set by the "General" key at the begining of the process.
#     <br>
#     Each row of the files are copied according their zone clasification in their corresponding folder path.
# </div>

# %%
# File paths
#power_plants_raw_data_sources_file_path = '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2020_power_plants_raw_data_sources_20240407_191506/2020_power_plants_raw_data_sources_20240407_191506.csv'

# Dictionary of created zones
#created_zones = {'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE',
#                 'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK',
#                 'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH',
#                'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE'}

# Read the first file
first_df = pd.read_csv(power_plants_raw_data_sources_file_path)

# Filter rows with Zone as "General"
general_zones_df = first_df[first_df['Zone'] == 'General']

# Iterate over rows with Zone as "General"
for index, row in general_zones_df.iterrows():
    # Get the path of the corresponding file
    file_path = row['Final_Clean_File_Path']
    
    # Read the second CSV file
    second_df = pd.read_csv(file_path)
    
    # Iterate over zone names
    for zone in zone_names:
        # Filter rows in the second file with matching Zone
        zone_rows = second_df[second_df['Zone'] == zone]
        
        # Check if there are matching rows
        if not zone_rows.empty:
            # Get the corresponding zone path
            zone_path = created_zones.get(zone)
            
            # Create the directory if it does not exist
            if not os.path.exists(zone_path):
                os.makedirs(zone_path)
            
            # Get the file name
            file_name = os.path.basename(file_path)
            zone_file_path = os.path.join(zone_path, file_name)
            
            # Copy the rows to the corresponding zone file
            if not os.path.exists(zone_file_path):
                zone_rows.to_csv(zone_file_path, index=False)
            else:
                zone_rows.to_csv(zone_file_path, mode='a', index=False, header=False)
            
            # Remove the copied rows from the original DataFrame
            second_df.drop(zone_rows.index, inplace=True)
            
            # Print message
            print(f"Copied rows to {zone_file_path} for zone {zone}.")
    
    # Write the updated DataFrame back to the second file
    second_df.to_csv(file_path, index=False)
    print(f"Original file {file_path} updated after row deletion.")

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     9. Zone Clustering
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Grouping power units according the location, the company or the name.
#     <br>
#     This part is set to make a cluster of all the units that have the same Latitud and Longitud location (if the data is provided)
#      <br>
#     However, there is the posibility to cluster the units by the name for all the units that has the same name or by the company (if the data is also provided).
#     <br>
#     To do it, just Uncomment the corresponding line of the following lines of the code.
# </div>
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     9.1. Lat/Lon Column Creation
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Joining the filed of the columns Lat and Lon into a new column under the name Lat/Lon to clustering purposes.
# </div>

# %%
#created_zones = {
#    'DE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE',
#    'DK': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK',
#    'CH': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH',
#    'BE': '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE'
#}

#data_year = '2020'

power_plants_clean_data_file_path_list = []

# Extract and format paths
for zone, path in created_zones.items():
  full_path = f"{path}/{data_year}.csv"
  power_plants_clean_data_file_path_list.append(full_path)

# Print the list of paths
print(power_plants_clean_data_file_path_list)
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv', '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %%
power_plants_clean_data_file_path_list
# Out:
# ['/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv',
#  '/home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv']

# %%
for file_path in power_plants_clean_data_file_path_list:
  # Read the CSV file
  df = pd.read_csv(file_path)

  # Check if "Lat" and "Lon" columns exist
  if 'Lat' in df.columns and 'Lon' in df.columns:
    # Create a new column named "Lat+Lon" with empty string as default
    df['Lat/Lon'] = np.where((df['Lat'].notna()) & (df['Lon'].notna()), df['Lat'].astype(str) + "/" + df['Lon'].astype(str), '')

    # Save the modified DataFrame back to the CSV file
    df.to_csv(file_path, index=False)
  else:
    print(f"Warning: 'Lat' or 'Lon' column not found in {file_path}")

print("Lat/Lon column added to files (if columns exist).")
# Out:
# Lat/Lon column added to files (if columns exist).

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
#     9.2. Fields Cluster
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Clustering the units with the repeated values in the Lat/Lon.
#      <br>
#     The next code just clusters the units which Latitud and longitud repeated values under the condition that have the same Technology, Fuel and CHPType as well.
#     <br>
#     This process is made for each zone.
#     <br>
#     There is the posibility to make a cluster looking for duplicate fields in the name of the units or the company (If the data exists). For this purpouse just uncomend the corresponding lines.
# </div>

# %%
# Column to be looked for
column_to_look_for = 'Lat/Lon'  # Change 'YourColumnNameHere' to the actual column name
#column_to_look_for = 'Unit'
#column_to_look_for = 'Company'


# Iterate over each file
for file_path in power_plants_clean_data_file_path_list:
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Check if the column to look for exists
    if column_to_look_for in df.columns:
        # Iterate over each value in the specified column
        for value in df[column_to_look_for].unique():
            # Check if the field has some value
            if pd.notnull(value):
                # Filter rows where the specified column has the exact same value
                matched_rows = df[df[column_to_look_for] == value]

                # Check if there are more than one row with the same value
                if len(matched_rows) > 1:
                    # Perform additional matching based on Technology, Fuel, and CHPType
                    # You can adjust the conditions as per your requirement
                    matched_rows = matched_rows.groupby(['Technology', 'Fuel', 'CHPType']).filter(lambda x: len(x) > 1)

                    if len(matched_rows) > 1:
                        # Sum the corresponding fields
                        summed_fields = matched_rows[['PowerCapacity', 'Nunits', 'StartUpCost', 'NoLoadCost_pu',
                                                       'RampingCost', 'CHPPowerToHeat', 'CHPMaxHeat', 'STOCapacity',
                                                       'WaterWithdrawal', 'WaterConsumption']].sum()

                        # Calculate the average of the corresponding fields
                        averaged_fields = matched_rows[['Efficiency', 'MinUpTime', 'MinDownTime', 'RampUpRate',
                                                         'RampDownRate', 'PartLoadMin', 'MinEfficiency', 'StartUpTime',
                                                         'CO2Intensity', 'CHPPowerLossFactor', 'CHPMaxHeat', 'COP',
                                                         'Tnominal', 'coef_COP_a', 'coef_COP_b', 'STOSelfDischarge',
                                                         'STOMaxChargingPower', 'STOChargingEfficiency']].mean()

                        # Keep the first row and update its values with the sums and averages
                        first_row_index = matched_rows.index[0]
                        df.loc[first_row_index, ['PowerCapacity', 'Nunits', 'StartUpCost', 'NoLoadCost_pu',
                                                 'RampingCost', 'CHPPowerToHeat', 'CHPMaxHeat', 'STOCapacity',
                                                 'WaterWithdrawal', 'WaterConsumption']] = summed_fields
                        df.loc[first_row_index, ['Efficiency', 'MinUpTime', 'MinDownTime', 'RampUpRate',
                                                 'RampDownRate', 'PartLoadMin', 'MinEfficiency', 'StartUpTime',
                                                 'CO2Intensity', 'CHPPowerLossFactor', 'CHPMaxHeat', 'COP',
                                                 'Tnominal', 'coef_COP_a', 'coef_COP_b', 'STOSelfDischarge',
                                                 'STOMaxChargingPower', 'STOChargingEfficiency']] = averaged_fields

                        # Copy the matched rows to a new DataFrame
                        clustered_df = matched_rows.copy()

                        # Write the matched rows to a new CSV file
                        output_file_path = os.path.splitext(file_path)[0] + '_clustered.csv'
                        clustered_df.to_csv(output_file_path, index=False)

                        # Erase the rows from the original DataFrame
                        df.drop(matched_rows.index, inplace=True)

    # Write the modified DataFrame back to the original CSV file
    df.to_csv(file_path, index=False)

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
# 10. Copying Power Plants Formatted Data
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Moving the already clean and formatted data of the power units to the main Dispa-SET data base directory.
#      <br>
#     <div style="text-align: left; margin-left: 2.0em; font-weight: unbold; font-size: 15px; font-family: TimesNewRoman;">
#     - The data base directory has to be identified.
# </div>

# %%
additional_path_1 = "/Database/PowerPlants/"

# Construct the power_plants_raw_data_folder_path variable
power_plants_data_base_folder_path = dispaSET_unleash_folder_path + additional_path_1

# %%
# Iterate over each zone in the list
for zone in zone_names:
    # Define the source file path
    source_file_path = os.path.join(power_plants_raw_data_folder_path, zone, f"{data_year}.csv")
    
    # Define the destination folder path
    destination_folder_path = os.path.join(power_plants_data_base_folder_path, zone)
    
    # Define the destination file path
    destination_file_path = os.path.join(destination_folder_path, f"{data_year}.csv")
    
    # Check if the source file exists
    if os.path.exists(source_file_path):
        # Ensure the destination folder exists
        os.makedirs(destination_folder_path, exist_ok=True)
        
        # Copy the file
        shutil.copyfile(source_file_path, destination_file_path)
        print(f"Copied {source_file_path} to {destination_file_path}")
    else:
        print(f"Source file does not exist: {source_file_path}")

print("Task completed.")
# Out:
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/AT/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/BE/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/BG/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/CH/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/CY/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/CZ/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/DE/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/DK/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/EE/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/EL/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/ES/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/FI/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/FR/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/HR/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/HU/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/IE/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/IT/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/LT/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/LU/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/LV/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/MT/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/NL/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/NO/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/PL/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/PT/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/RO/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/SE/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/SI/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/SK/2023.csv
# Copied /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv to /home/ray/Dispa-SET_Unleash/Database/PowerPlants/UK/2023.csv
# Task completed.

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 17px; font-family: TimesNewRoman;">
# 10. Power Plants Raw Data Folder Cleaning
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Returning the folder of the power plant raw data to its original state
# </div>

# %%
# Convert folder_file_names to absolute paths for comparison
folder_file_names = [os.path.abspath(name) for name in folder_file_names]

# Function to delete items not in the list
def delete_unlisted_items(folder, listed_items):
    for root, dirs, files in os.walk(folder, topdown=False):
        for name in files:
            file_path = os.path.join(root, name)
            if os.path.abspath(file_path) not in listed_items:
                os.remove(file_path)
                print(f"Deleted file: {file_path}")

        for name in dirs:
            dir_path = os.path.join(root, name)
            if os.path.abspath(dir_path) not in listed_items:
                shutil.rmtree(dir_path)
                print(f"Deleted folder: {dir_path}")

# Delete unlisted items
delete_unlisted_items(power_plants_raw_data_folder_path, folder_file_names)
# Out:
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE/19
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/6
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/25
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/28
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/13
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT/21
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/26
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/23
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI/31
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/32
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/5
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR/17
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/4
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/11
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/1
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/29
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/14
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/3
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/22
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/20
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/33
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK/34
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR/16
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240727_142444/2023_power_plants_raw_data_sources_20240727_142444.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI/15
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT/24
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/7
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/9
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/10
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE/8
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/27
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/30
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/12
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/power_plants_all_data_not_defined_units.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/2023.csv
# Deleted file: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU/18
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IE
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CZ
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NL
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PT
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EL
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LT
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/NO
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LV
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SI
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SK
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CY
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HR
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/CH
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DK
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/AT
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/RO
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/ES
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BG
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/LU
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/IT
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/UK
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FR
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/2023_power_plants_raw_data_sources_20240727_142444
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/FI
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/BE
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/MT
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/DE
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/PL
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/SE
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/EE
# Deleted folder: /home/ray/Dispa-SET_Unleash/RawData/PowerPlants/HU

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     11. Final considerations
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     All the files with the appropiated format needed for Dispa-SET simulations are located at the folders named as the created zone entered in section 3 and follows the next path patron:
#     Local/paht/to/dispa-SET/folder/RawData/PowerPlants/zone_created
#     <br>
#     All the formated files are named with the value introduced in the variable "data_year" entered in section 4
#      <br>
#     The files can be copied to the needed location to into the Dispa-SET directory envinronment.
#     <br>
#     In the other hand, the formated files still contain columns that are not usefull for Dispa-SET runs, however as the same are not taken account for the simulation those columns can be removed manually or not. In future version of this code is going to be implemented a final stept ot eliminate these columns automatically
# </div>
