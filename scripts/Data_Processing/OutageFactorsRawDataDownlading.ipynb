# %% [markdown]
# <div style="text-align: center; margin-left: 0em; font-weight: bold; font-size: 20px; font-family: TimesNewRoman;">
#     TIME SERIES DATA PROCESSING | OUTAGE FACTORS - Downloading Notebook
# </div>
#
# <div style="text-align: left; margin-left: 0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# Each part of the following script was used to donwload the raw data for the Outage Factors Time Series Raw Data for all the european countries of the Dispa-SET_Unleash project.
# <br>
# Read explanation text cells to follow and understand all the process until final results were got stept by step.
# </div>
# <br>
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     1. Notebook Set Up
# </div>
#
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Importing needed libraries
# </div>

# %%
import pandas as pd
from entsoe import EntsoePandasClient
import os

# %% [markdown]
#  <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     2. ENTSO-E RESTful API.
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# Connecting with the ENTSO-E API Tool.
# </div>
# <div style="text-align: left; margin-left: 2.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# - To donwload the neeeded data using the API tool, is mandatory to use a token autentication to connect and make the future request of data.
# </div>

# %%
client = EntsoePandasClient(api_key='61e5bbbb-7e80-4540-a471-bd993873aa74')

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     3. Dispa-SET_Unleash Folder Path
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
#     Determinning dynamically the zone_folder_path based on the location of the "Dispa-SET_Unleash" folder relative to the current working directory.
# </div>
# <div style="text-align: left; margin-left: 2.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# - If the "Dispa-SET_Unleash" folder is copied to a different machine or location, the dispaSET_unleash_folder_path variable will automatically adjust accordingly.
# </div>

# %%
# Get the current working directory
current_directory = os.getcwd()

# Navigate to the parent directory of "Dispa-SET_Unleash"
dispaSET_unleash_parent_directory = os.path.dirname(current_directory)

# Get the path to the "Dispa-SET_Unleash" folder
dispaSET_unleash_folder_path = os.path.dirname(dispaSET_unleash_parent_directory)

# Construct the dispaSET_unleash_folder_name variable
dispaSET_unleash_folder_name = os.path.basename(dispaSET_unleash_folder_path)

print("dispaSET_unleash_folder_name:", dispaSET_unleash_folder_name)
print("dispaSET_unleash_folder_path:", dispaSET_unleash_folder_path)
# Out:
# dispaSET_unleash_folder_name: Dispa-SET_Unleash
# dispaSET_unleash_folder_path: /home/ray/Dispa-SET_Unleash

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     4. Usefull Variable Definition
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# Entering a value to all the variables which content are going to be used in some of the next stages of this script.
# </div>
# <div style="text-align: left; margin-left: 2.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# - Indicate the year of all data is referring to in the variable data_year.
# <br>
# - The universal_standar_time variable is going to be used to download all the time series data in this horary zone. Additionally as each european country belongs a particular time sector the corresponding time series data related to its time sector are going to be downloaded as well but in a different file.
# <br>
# - Additionally there are some default parameters that has to be defined to the correct working and calling to the ENTSO-E downloading functions.
# </div>

# %%
# Year to which data refers to:
data_year = 2023

# %%
# Additional string to be appended
additional_path = "/RawData/OutageFactors/"
additional_path_1 = "/RawData/OutageFactors/Raw_Data_Sources"

# Construct the standard_time_data_folder_path variable
reference_data_folder_path = dispaSET_unleash_folder_path + additional_path

# Construct the Outage_Factors_folder_path variable
outage_factor_folder_path = dispaSET_unleash_folder_path + additional_path

# Construct the Outage_Factors_Raw_Data_folder_path variable
outage_factors_raw_data_folder_path = dispaSET_unleash_folder_path + additional_path_1


print("reference_data_folder_path:", reference_data_folder_path)
print("outage_factor_folder_path:", outage_factor_folder_path)
print("outage_factors_raw_data_folder_path:", outage_factors_raw_data_folder_path)
# Out:
# reference_data_folder_path: /home/ray/Dispa-SET_Unleash/RawData/OutageFactors/
# outage_factor_folder_path: /home/ray/Dispa-SET_Unleash/RawData/OutageFactors/
# outage_factors_raw_data_folder_path: /home/ray/Dispa-SET_Unleash/RawData/OutageFactors/Raw_Data_Sources

# %%
# Define other parameters
type_marketagreement_type = 'A01'
contract_marketagreement_type = "A01"
process_type = 'A51'

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     5. Country List Variable Definition
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# Defining the list of countries according to the available data .
# </div>
# <div style="text-align: left; margin-left: 2.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# - Since not all the Countries modelled in Dispa-SET has available data in the ENTSO-E API and also some countries are not be able to get the same kind of data e.g. The outages of Germany, Denmark and others cannot be downloaded, they are going to be avoided of the outages country to not interrupt the downloading proccess.
# </div>

# %%
# Define a list of country codes
#country_list = ["AT", "BE", "BG", "CH", "CY", "CZ", "DE", "DK", "EE", "EL", "ES", "FI", "FR", "HR", "HU", 
#               "IE", "IT", "LT", "LU", "LV", "MT", "NL", "NO", "PL", "PT", "RO", "SE", "SI", "SK", "UK"]

outages_data_per_unit_country_list = ["DE", "DK", "ES", "FR", "IT"]

non_outages_data_country_list = ["CY", "HR", "LU", "MT", "DE", "DK", "ES", "FR", "IT"]

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     6. Outages Data Per Unit Downloading
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# Downloading the outages raw data which countries have a desagregation per unit.
# </div>

# %%
# Iterate over each country code
for country_code in outages_data_per_unit_country_list:
    # Define the start and end timestamps for the year
    start = pd.Timestamp(str(data_year) + '0101', tz='Europe/Brussels')
    end = pd.Timestamp(str(data_year) + '1231', tz='Europe/Brussels')

    # Query unavailability of generation units for the current country code
    query_unavailability_of_generation_units = client.query_unavailability_of_generation_units(country_code, start=start, end=end, docstatus=None, periodstartupdate=None, periodendupdate=None)

    # Define the output folder path using the country code
    output_folder_path = os.path.join(outage_factors_raw_data_folder_path, str(data_year))
    os.makedirs(output_folder_path, exist_ok=True)  # Create the folder if it doesn't exist

    # Define the output file path using the country code
    output_file_path = os.path.join(output_folder_path, f'{country_code}.csv')
    
    # Save the queried data to a CSV file
    query_unavailability_of_generation_units.to_csv(output_file_path, index=False)
# Out:
# Connection Error, retrying in 0 seconds
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202312302300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 98828 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202307012300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 48714 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202304012300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 24542 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202302151100
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 12618 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202301231700
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 7164 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202301120800
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 4178 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202301061600
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 2613 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202301031900
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 2001 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202301020900
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1733 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202301011600
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1591 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202301010800
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1565 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202301010300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1531 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202301010100
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1515 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202301010000
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1039 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202301010000
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1039 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# ...
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 48, in pagination_wrapper
#     df = func(*args, start=start, end=end, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 69, in documents_wrapper
#     frame = func(*args, offset=offset, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 1951, in _query_unavailability
#     content = super(EntsoePandasClient, self)._query_unavailability(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 982, in _query_unavailability
#     response = self._base_request(params=params, start=start, end=end)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/decorators.py", line 24, in retry_wrapper
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 114, in _base_request
#     raise PaginationError(
# entsoe.exceptions.PaginationError: The API is limited to 200 elements per request. This query requested for 1026 documents and cannot be fulfilled as is.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/entsoe/entsoe.py", line 99, in _base_request
#     response.raise_for_status()
#   File "/home/ray/anaconda3/lib/python3.11/site-packages/requests/models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A80&biddingZone_domain=10Y1001A1001A83F&offset=0&securityToken=61e5bbbb-7e80-4540-a471-bd993873aa74&periodStart=202212312300&periodEnd=202212312300
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# <div style="text-align: left; margin-left: 3.0em; font-weight: bold; font-size: 18px; font-family: TimesNewRoman;">
#     8. Non Outages Data
# </div>
# <div style="text-align: left; margin-left: 0.0em; font-weight: unbold; font-size: 16px; font-family: TimesNewRoman;">
# Creating empty csv files with the corresponding headers for those countries which outages raw data are not available.
# </div>
